# %% [markdown]
# # Principal component Analysis Assignment
# """
# Perform Principal component analysis and perform clustering using first
# 3 principal component scores (both heirarchial and k mean clustering(scree plot or elbow curve) and obtain
# optimum number of clusters and check whether we have obtained same number of clusters with the original data
# (class column we have ignored at the begining who shows it has 3 clusters)df

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import probplot
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
import scipy.cluster.hierarchy as shc
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
## warnings ignoring
import warnings
warnings.filterwarnings("ignore")

# %%
## loading data set
df=pd.read_csv("wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
## EDA 
list(df)
# Out:
# ['Type',
#  'Alcohol',
#  'Malic',
#  'Ash',
#  'Alcalinity',
#  'Magnesium',
#  'Phenols',
#  'Flavanoids',
#  'Nonflavanoids',
#  'Proanthocyanins',
#  'Color',
#  'Hue',
#  'Dilution',
#  'Proline']

# %%
df.shape
# Out:
# (178, 14)

# %%
# Checking null values and data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
# correlation
df.corr()
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
###---Histogram---###
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(13,10))
h1 = ['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols', 'Flavanoids', 'Nonflavanoids',
      'Proanthocyanins', 'Color', 'Hue', 'Dilution', 'Proline']
colors = sns.color_palette('viridis', n_colors=len(h1))
for i, (variable, color) in enumerate(zip(h1, colors)):
    sns.histplot(data=df, x=variable, ax=axes[i // 2, i % 2], color=color, bins=20)
plt.tight_layout()
plt.show()

# %%
###---BOX-PLOT--###
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(13,10))
h1 = ['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols', 'Flavanoids', 'Nonflavanoids',
      'Proanthocyanins', 'Color', 'Hue', 'Dilution', 'Proline']
colors = sns.color_palette('viridis', n_colors=len(h1))
for i, (variable, color) in enumerate(zip(h1, colors)):
    sns.boxplot(data=df, x=variable, ax=axes[i // 2, i % 2],color=color)
plt.tight_layout()
plt.show()

# %%
##--- OUTLIERS---###
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(13, 10))
h1 = ['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols', 'Flavanoids', 'Nonflavanoids',
      'Proanthocyanins', 'Color', 'Hue', 'Dilution', 'Proline']
colors = sns.color_palette('viridis', n_colors=len(h1))
def calculate_outliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = (data < lower_bound) | (data > upper_bound)
    return outliers
for i, (variable, color) in enumerate(zip(h1, colors)):
    outliers = calculate_outliers(df[variable])
    sns.boxplot(data=df, x=variable, ax=axes[i // 2, i % 2], color=color)
    axes[i // 2, i % 2].plot([], [], marker='o', linestyle='None', color='red', label='Outliers')
    axes[i // 2, i % 2].legend()
plt.tight_layout()
plt.show()

# %%
###----SCATTER-PLOT---##
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(13,10))
h1 = ['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols', 'Flavanoids', 'Nonflavanoids',
      'Proanthocyanins', 'Color', 'Hue', 'Dilution', 'Proline']
colors = sns.color_palette('viridis', n_colors=len(h1))
for i, (variable, color) in enumerate(zip(h1, colors)):
    sns.scatterplot(data=df, x=variable, y='Proline', hue='Hue', ax=axes[i // 2, i % 2], palette='viridis')
plt.tight_layout()
plt.show()

# %%
##---pair plot---###
sns.pairplot(df)
plt.show()

# %%
##---DISTRIBUTION PLOT--###
dsplot = ['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols', 'Flavanoids', 'Nonflavanoids',
      'Proanthocyanins', 'Color', 'Hue', 'Dilution', 'Proline']
fig, axes = plt.subplots(nrows=2, ncols=7, figsize=(12, 8))
axes = axes.flatten()
for i, column in enumerate(dsplot):
    sns.histplot(data=df, x=column, kde=True, ax=axes[i], color='deepskyblue')
    axes[i].set_title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# %%
###---Q-Q-plot---##
qqplot = ['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols', 'Flavanoids', 'Nonflavanoids',
          'Proanthocyanins', 'Color', 'Hue', 'Dilution', 'Proline']
fig, axes = plt.subplots(nrows=2, ncols=7, figsize=(12,10))
axes = axes.flatten()
for i, column in enumerate(qqplot):
    sns.histplot(data=df, x=column, kde=True, ax=axes[i], color='darkorange')
    axes[i].set_title(f'Distribution of {column}')
    _, (slope, intercept, r) = probplot(df[column], plot=axes[i])
    axes[i].set_title(f'Distribution of {column}\nR-squared: {r**2:.2f}')
plt.tight_layout()
plt.show()

# %%
## PCA Analysis

# %%
## X accessing
X=df.iloc[:,0:]

# %%
X
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
##--LabelEncoding---
LE=LabelEncoder()

# %%
###----Standardization---###
SS=StandardScaler()
SS_X=SS.fit_transform(X)
pd.DataFrame(SS_X)
SS_X
# Out:
# array([[-1.21394365,  1.51861254, -0.5622498 , ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [-1.21394365,  0.24628963, -0.49941338, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [-1.21394365,  0.19687903,  0.02123125, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 1.37386437,  0.33275817,  1.74474449, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 1.37386437,  0.20923168,  0.22769377, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.37386437,  1.39508604,  1.58316512, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
###--- converting into data frames
pd.DataFrame(SS_X)
# Out:
#            0         1         2         3         4         5         6   \
# 0   -1.213944  1.518613 -0.562250  0.232053 -1.169593  1.913905  0.808997
# 1   -1.213944  0.246290 -0.499413 -0.827996 -2.490847  0.018145  0.568648
# 2   -1.213944  0.196879  0.021231  1.109334 -0.268738  0.088358  0.808997
# 3   -1.213944  1.691550 -0.346811  0.487926 -0.809251  0.930918  2.491446
# 4   -1.213944  0.295700  0.227694  1.840403  0.451946  1.281985  0.808997
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  1.373864  0.876275  2.974543  0.305159  0.301803 -0.332922 -0.985614
# 174  1.373864  0.493343  1.412609  0.414820  1.052516  0.158572 -0.793334
# 175  1.373864  0.332758  1.744744 -0.389355  0.151661  1.422412 -1.129824
# 176  1.373864  0.209232  0.227694  0.012732  0.151661  1.422412 -1.033684
# 177  1.373864  1.395086  1.583165  1.365208  1.502943 -0.262708 -0.392751
#
#            7         8         9         10        11        12        13
# ...

# %%
###---Principal component analysis--###
pc = PCA()
pc_df  = pc.fit_transform(SS_X)
pc_df = pd.DataFrame(pc_df)
pc_df
# Out:
#            0         1         2         3         4         5         6   \
# 0   -3.522934 -1.453098 -0.164795 -0.013273  0.737345 -0.300716  0.573876
# 1   -2.528858  0.330019 -2.026707 -0.417144 -0.283214 -0.884309 -0.029716
# 2   -2.785029 -1.036936  0.983238  0.664232 -0.387565  0.468842  0.488305
# 3   -3.922588 -2.768210 -0.174968  0.565088 -0.324360  0.262616 -0.398364
# 4   -1.407511 -0.867773  2.025829 -0.440906  0.227949 -0.593762  0.447876
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  3.627996 -2.206617 -0.343668  0.751705 -1.004109 -1.143155  0.843455
# 174  2.942729 -1.752263  0.207480  0.399381  0.154223 -0.062465  0.139947
# 175  3.027272 -2.756040 -0.940803  0.607758  1.128136  0.005290  0.733026
# 176  2.755222 -2.293784 -0.550474 -0.391570  1.067083  1.012562  0.755423
# 177  3.496336 -2.760608  1.013151  0.349630 -1.005136  0.377223  0.015307
#
#            7         8         9         10        11        12        13
# ...

# %%
##--variance of each---##
pc_df.iloc[0].var()
pc_df.iloc[1].var()
pc_df.iloc[2].var()
# Out:
# 0.9558967845547823

# %%
pd.DataFrame((pc.explained_variance_ratio_)*100)
# Out:
#             0
# 0   39.542486
# 1   17.836259
# 2   10.329102
# 3    6.627984
# 4    6.267875
# 5    4.805560
# 6    3.955707
# 7    2.500244
# 8    2.103871
# 9    1.873615
# 10   1.613203
# 11   1.205691
# 12   0.925458
# 13   0.412945

# %%
###-- plot for-pc.explained_variance_ratio--- 
plt.scatter(range(0,14),pd.DataFrame((pc.explained_variance_ratio_)*100))
plt.show()

# %%
###---Using first 3 PCA---### 
X_new = pc_df.iloc[:,0:3]
X_new
# Out:
#             0         1         2
# 0   -3.522934 -1.453098 -0.164795
# 1   -2.528858  0.330019 -2.026707
# 2   -2.785029 -1.036936  0.983238
# 3   -3.922588 -2.768210 -0.174968
# 4   -1.407511 -0.867773  2.025829
# ..        ...       ...       ...
# 173  3.627996 -2.206617 -0.343668
# 174  2.942729 -1.752263  0.207480
# 175  3.027272 -2.756040 -0.940803
# 176  2.755222 -2.293784 -0.550474
# 177  3.496336 -2.760608  1.013151
#
# [178 rows x 3 columns]

# %%
### -- K - MEANS ---####
KMeans=KMeans(n_clusters=5,n_init=30)
KMeans.fit(X_new)
# Out:
# KMeans(n_clusters=5, n_init=30)

# %%
Y=KMeans.predict(X_new)
Y=pd.DataFrame(Y)
Y[0].value_counts()
# Out:
# 2    49
# 0    43
# 1    35
# 3    30
# 4    21
# Name: 0, dtype: int64

# %%
###--- inertia value ----###
KMeans.inertia_
# Out:
# 355.7392759912641

# %%
inertia=[]
from sklearn.cluster import KMeans

for i in range(1,11):
    km=KMeans(n_clusters=i,random_state=0)
    km.fit(X_new)
    inertia.append(km.inertia_)

# %%
#---Elbow method-curve--    
plt.scatter(range(1,11),inertia)
plt.plot(range(1,11),inertia,color='darkviolet')
plt.title('Elbow method')
plt.xlabel(' PCA clusters')
plt.ylabel('inertia')
plt.show()

# %%
## -- Agglomerative clustering --- ###
cluster=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')
Y=cluster.fit_predict(X_new)
Y=pd.DataFrame(Y)
Y.value_counts()
# Out:
# 2    56
# 1    48
# 0    41
# 3    29
# 4     4
# dtype: int64

# %%
## -- Dendogram---###
plt.figure(figsize=(10,7))
plt.title("PCA Dendograms")
dend=shc.dendrogram(shc.linkage(X,method='single'))
